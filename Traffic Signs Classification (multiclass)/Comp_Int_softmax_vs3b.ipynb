# %% [markdown]
# Download and unzip dataset

# %%
import requests
from io import BytesIO
from zipfile import ZipFile
dataset = requests.get("https://www.dropbox.com/s/04r31l2whoyljz7/trafficsigns.zip?dl=1")
with ZipFile(BytesIO(dataset.content)) as z:
  z.extractall(".")
classlabels = requests.get("https://www.dropbox.com/s/lte4x88xdk9x4k2/classlabels.txt?dl=1")
with open("classlabels.txt", 'w') as outfile:
  outfile.write(classlabels.content.decode('utf-8'))

# %% [markdown]
# Read training set and test set

# %%
from tensorflow.keras.utils import load_img, image_dataset_from_directory
training_set = [(i, l) for i, l in image_dataset_from_directory('trafficsigns/train', image_size = (128, 128), batch_size = None, seed = 123)]
test_set = [(i, l) for i, l in image_dataset_from_directory('trafficsigns/test', image_size = (128, 128), batch_size = None, seed = 123)]

import json
with open("classlabels.txt") as infile:
  labels = dict((int(i), j) for i, j in json.loads(infile.read()).items())
print("The 20 classes are: " + ", ".join(str(l) for l in labels.values()))
# Out:
# Found 1792 files belonging to 20 classes.
# Found 1022 files belonging to 20 classes.
# The 20 classes are: limit30, limit50, limit60, limit80, noleft, noright, nouturn, gostraight, goleft, goright, keepright, roundabout, danger, pedestrcross, bikecross, childcross, traincross, construction, nostopping, noentry

# %% [markdown]
# Keep only specific class labels

# %%
from ctypes import sizeof
labels_to_keep = list(range(20)) # Change this to determine which labels to keep (or change to list(range(20)) to keep all labels)
num_classes = len(labels_to_keep)

import numpy as np
x_train = np.array([image for image, label in training_set if label in labels_to_keep])
y_train = np.array([labels_to_keep.index(label) for image, label in training_set if label in labels_to_keep])
x_test = np.array([image for image, label in test_set if label in labels_to_keep])
y_test = np.array([labels_to_keep.index(label) for image, label in test_set if label in labels_to_keep])


finallabels = dict([(i, labels[l]) for i, l in enumerate(labels_to_keep)])
print("The " + str(num_classes) + " classes are: " + ", ".join(str(l) for l in finallabels.values()))
# Out:
# The 20 classes are: limit30, limit50, limit60, limit80, noleft, noright, nouturn, gostraight, goleft, goright, keepright, roundabout, danger, pedestrcross, bikecross, childcross, traincross, construction, nostopping, noentry

# %% [markdown]
# Plot example data

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import array_to_img
fig = plt.figure()
for i in range(15):
  plt.subplot(3,5,i+1)
  plt.tight_layout()
  img = array_to_img(x_train[i])
  plt.imshow(img)
  plt.title(finallabels[y_train[i]])
  plt.xticks([])
  plt.yticks([])

# %% [markdown]
# Set model parameters and use the image data format of Tensorflow

# %%
img_width, img_height = 128, 128
input_shape = (img_width, img_height, 3)

# %%
import keras
num_classes = 20
y_train = keras.utils.np_utils.to_categorical(y_train, num_classes)
y_test = keras.utils.np_utils.to_categorical(y_test, num_classes)

# %% [markdown]
# Create a neural network with 4 convolutional layers and 2 dense layers

# %%
from keras.layers import Convolution2D, MaxPooling2D, Dropout, Flatten, Dense,BatchNormalization
from keras.models import Sequential

model = Sequential()
model.add(Convolution2D(32, (5, 5), activation='relu', input_shape=input_shape))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Convolution2D(32, (5, 5), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Convolution2D(32, (5, 5), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Convolution2D(64, (5, 5), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.35))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.summary()
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 124, 124, 32)      2432
#
#  batch_normalization (BatchN  (None, 124, 124, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 62, 62, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 58, 58, 32)        25632
#
#  batch_normalization_1 (Batc  (None, 58, 58, 32)       128
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 29, 29, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 32)        25632
#
#  batch_normalization_2 (Batc  (None, 25, 25, 32)       128
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 64)          51264
#
#  batch_normalization_3 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  dropout (Dropout)           (None, 4, 4, 64)          0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 128)               131200
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 20)                2580
#
# =================================================================
# Total params: 239,380
# Trainable params: 239,060
# Non-trainable params: 320
# _________________________________________________________________

# %% [markdown]
# Perform augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(rescale=1. / 255, shear_range=0.2, zoom_range=0.2,brightness_range=[0.4,0.9], validation_split=0.3)
test_datagen=ImageDataGenerator(rescale=1. / 255, shear_range=0.2, zoom_range=0.2,brightness_range=[0.4,0.9])

# %% [markdown]
# Train the model

# %%
history=model.fit(datagen.flow(x_train,y_train,batch_size=16,seed=0,subset='training'),steps_per_epoch=len(x_train)*0.3// 16,epochs=50,verbose=1,validation_data=datagen.flow(x_train,y_train,batch_size=16,seed=0,subset='validation'),shuffle=True)
# Out:
# Epoch 1/50
# 33/33 [==============================] - 30s 863ms/step - loss: 3.0741 - accuracy: 0.3237 - val_loss: 3.0418 - val_accuracy: 0.1434
# Epoch 2/50
# 33/33 [==============================] - 28s 864ms/step - loss: 1.7544 - accuracy: 0.5341 - val_loss: 3.1196 - val_accuracy: 0.1881
# Epoch 3/50
# 33/33 [==============================] - 28s 862ms/step - loss: 1.2123 - accuracy: 0.6496 - val_loss: 3.1881 - val_accuracy: 0.1210
# Epoch 4/50
# 33/33 [==============================] - 28s 848ms/step - loss: 1.1203 - accuracy: 0.6744 - val_loss: 2.7169 - val_accuracy: 0.1657
# Epoch 5/50
# 33/33 [==============================] - 28s 849ms/step - loss: 0.8806 - accuracy: 0.7187 - val_loss: 2.3483 - val_accuracy: 0.2216
# Epoch 6/50
# 33/33 [==============================] - 28s 862ms/step - loss: 0.8550 - accuracy: 0.7405 - val_loss: 1.6467 - val_accuracy: 0.4842
# Epoch 7/50
# 33/33 [==============================] - 28s 851ms/step - loss: 0.4913 - accuracy: 0.8285 - val_loss: 2.2432 - val_accuracy: 0.2905
# Epoch 8/50
# 33/33 [==============================] - 28s 852ms/step - loss: 0.4880 - accuracy: 0.8266 - val_loss: 1.9684 - val_accuracy: 0.4153
# Epoch 9/50
# 33/33 [==============================] - 28s 864ms/step - loss: 0.3431 - accuracy: 0.8883 - val_loss: 2.1868 - val_accuracy: 0.3948
# Epoch 10/50
# 33/33 [==============================] - 28s 861ms/step - loss: 0.3479 - accuracy: 0.8826 - val_loss: 1.1229 - val_accuracy: 0.6238
# Epoch 11/50
# 33/33 [==============================] - 28s 861ms/step - loss: 0.2923 - accuracy: 0.9205 - val_loss: 0.6252 - val_accuracy: 0.7747
# Epoch 12/50
# 33/33 [==============================] - 28s 865ms/step - loss: 0.2255 - accuracy: 0.9242 - val_loss: 0.4323 - val_accuracy: 0.8101
# Epoch 13/50
# 33/33 [==============================] - 28s 851ms/step - loss: 0.2137 - accuracy: 0.9326 - val_loss: 0.2468 - val_accuracy: 0.9069
# Epoch 14/50
# 33/33 [==============================] - 28s 863ms/step - loss: 0.1677 - accuracy: 0.9413 - val_loss: 0.1822 - val_accuracy: 0.9385
# Epoch 15/50
# 33/33 [==============================] - 28s 850ms/step - loss: 0.1580 - accuracy: 0.9461 - val_loss: 0.1343 - val_accuracy: 0.9628
# Epoch 16/50
# 33/33 [==============================] - 28s 851ms/step - loss: 0.1082 - accuracy: 0.9595 - val_loss: 0.1152 - val_accuracy: 0.9721
# Epoch 17/50
# 33/33 [==============================] - 28s 851ms/step - loss: 0.1246 - accuracy: 0.9634 - val_loss: 0.1956 - val_accuracy: 0.9423
# Epoch 18/50
# 33/33 [==============================] - 28s 862ms/step - loss: 0.1629 - accuracy: 0.9583 - val_loss: 0.0526 - val_accuracy: 0.9851
# Epoch 19/50
# 33/33 [==============================] - 28s 862ms/step - loss: 0.1392 - accuracy: 0.9621 - val_loss: 0.0542 - val_accuracy: 0.9870
# Epoch 20/50
# 33/33 [==============================] - 28s 863ms/step - loss: 0.0942 - accuracy: 0.9754 - val_loss: 0.0425 - val_accuracy: 0.9888
# Epoch 21/50
# 33/33 [==============================] - 28s 862ms/step - loss: 0.0625 - accuracy: 0.9867 - val_loss: 0.0202 - val_accuracy: 0.9963
# Epoch 22/50
# 33/33 [==============================] - 28s 851ms/step - loss: 0.0713 - accuracy: 0.9750 - val_loss: 0.0342 - val_accuracy: 0.9907
# Epoch 23/50
# 33/33 [==============================] - 28s 862ms/step - loss: 0.0746 - accuracy: 0.9754 - val_loss: 0.0456 - val_accuracy: 0.9851
# Epoch 24/50
# 33/33 [==============================] - 28s 862ms/step - loss: 0.0792 - accuracy: 0.9735 - val_loss: 0.0272 - val_accuracy: 0.9851
# Epoch 25/50
# 33/33 [==============================] - 28s 851ms/step - loss: 0.0547 - accuracy: 0.9865 - val_loss: 0.0229 - val_accuracy: 0.9944
# Epoch 26/50
# 33/33 [==============================] - 28s 861ms/step - loss: 0.1243 - accuracy: 0.9640 - val_loss: 0.0306 - val_accuracy: 0.9944
# Epoch 27/50
# 33/33 [==============================] - 28s 862ms/step - loss: 0.0323 - accuracy: 0.9924 - val_loss: 0.0418 - val_accuracy: 0.9926
# Epoch 28/50
# 33/33 [==============================] - 28s 859ms/step - loss: 0.0960 - accuracy: 0.9697 - val_loss: 0.0739 - val_accuracy: 0.9777
# Epoch 29/50
# 33/33 [==============================] - 28s 859ms/step - loss: 0.0379 - accuracy: 0.9867 - val_loss: 0.0300 - val_accuracy: 0.9944
# Epoch 30/50
# 33/33 [==============================] - 28s 847ms/step - loss: 0.0748 - accuracy: 0.9807 - val_loss: 0.0969 - val_accuracy: 0.9870
# Epoch 31/50
# 33/33 [==============================] - 28s 849ms/step - loss: 0.0174 - accuracy: 0.9942 - val_loss: 0.0500 - val_accuracy: 0.9888
# Epoch 32/50
# 33/33 [==============================] - 28s 848ms/step - loss: 0.0319 - accuracy: 0.9865 - val_loss: 0.0229 - val_accuracy: 0.9907
# Epoch 33/50
# 33/33 [==============================] - 28s 852ms/step - loss: 0.0338 - accuracy: 0.9865 - val_loss: 0.0077 - val_accuracy: 0.9963
# Epoch 34/50
# 33/33 [==============================] - 28s 849ms/step - loss: 0.0160 - accuracy: 0.9942 - val_loss: 0.0389 - val_accuracy: 0.9944
# Epoch 35/50
# 33/33 [==============================] - 28s 861ms/step - loss: 0.0596 - accuracy: 0.9886 - val_loss: 0.0318 - val_accuracy: 0.9907
# Epoch 36/50
# 33/33 [==============================] - 28s 860ms/step - loss: 0.0408 - accuracy: 0.9811 - val_loss: 0.0719 - val_accuracy: 0.9870
# Epoch 37/50
# 33/33 [==============================] - 28s 860ms/step - loss: 0.0697 - accuracy: 0.9811 - val_loss: 0.0062 - val_accuracy: 0.9981
# Epoch 38/50
# 33/33 [==============================] - 28s 860ms/step - loss: 0.0312 - accuracy: 0.9905 - val_loss: 0.0169 - val_accuracy: 0.9944
# Epoch 39/50
# 33/33 [==============================] - 28s 859ms/step - loss: 0.0171 - accuracy: 0.9962 - val_loss: 0.0040 - val_accuracy: 0.9981
# Epoch 40/50
# 33/33 [==============================] - 28s 849ms/step - loss: 0.0278 - accuracy: 0.9884 - val_loss: 0.0645 - val_accuracy: 0.9832
# Epoch 41/50
# 33/33 [==============================] - 28s 860ms/step - loss: 0.0276 - accuracy: 0.9867 - val_loss: 0.0274 - val_accuracy: 0.9907
# Epoch 42/50
# 33/33 [==============================] - 28s 849ms/step - loss: 0.0166 - accuracy: 0.9904 - val_loss: 0.0881 - val_accuracy: 0.9814
# Epoch 43/50
# 33/33 [==============================] - 28s 859ms/step - loss: 0.0372 - accuracy: 0.9886 - val_loss: 0.0103 - val_accuracy: 0.9963
# Epoch 44/50
# 33/33 [==============================] - 28s 861ms/step - loss: 0.0338 - accuracy: 0.9924 - val_loss: 0.0248 - val_accuracy: 0.9926
# Epoch 45/50
# 33/33 [==============================] - 28s 850ms/step - loss: 0.0279 - accuracy: 0.9904 - val_loss: 0.0402 - val_accuracy: 0.9944
# Epoch 46/50
# 33/33 [==============================] - 28s 859ms/step - loss: 0.0332 - accuracy: 0.9867 - val_loss: 0.0139 - val_accuracy: 0.9963
# Epoch 47/50
# 33/33 [==============================] - 28s 848ms/step - loss: 0.0239 - accuracy: 0.9942 - val_loss: 0.0106 - val_accuracy: 0.9963
# Epoch 48/50
# 33/33 [==============================] - 28s 861ms/step - loss: 0.0398 - accuracy: 0.9886 - val_loss: 0.0166 - val_accuracy: 0.9926
# Epoch 49/50
# 33/33 [==============================] - 28s 849ms/step - loss: 0.0134 - accuracy: 0.9961 - val_loss: 0.0077 - val_accuracy: 0.9981
# Epoch 50/50
# 33/33 [==============================] - 28s 850ms/step - loss: 0.0436 - accuracy: 0.9865 - val_loss: 0.0070 - val_accuracy: 0.9981

# %% [markdown]
# Training and validation visualization

# %%
import matplotlib.pyplot as plt
train_acc=history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(1,51)
plt.plot(epochs, train_acc, 'g', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.xlim(1,50)
plt.ylim(0,1)
plt.grid(ls='dashed',c='grey')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1,51)
plt.plot(epochs, train_loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.xlim(1,50)
plt.ylim(0,3)
plt.grid(ls='dashed',c='grey')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Get loss and accuracy on test set

# %%
score = model.evaluate(test_datagen.flow(x_test, y_test,batch_size=16,seed=0), verbose=1)
print('Test accuracy:', score[1])
print('Test loss:',score[0])
# Out:
# 64/64 [==============================] - 13s 197ms/step - loss: 0.5409 - accuracy: 0.9119
# Test accuracy: 0.9119373559951782
# Test loss: 0.5409078001976013

# %% [markdown]
# Get Classification Report

# %%
from sklearn.metrics import classification_report, confusion_matrix

def cat_to_num(c):
  for i in range(len(c)+1):
    if c[i]==1:
      return i
test=test_datagen.flow(x_test, y_test,batch_size=16,seed=0)
y_true=[]
for i in range (64):
  b=test[i]
  b=b[1]
  for j in range(len(b)):
    y_true.append(cat_to_num(b[j]))
pred = model.predict(test).argmax(axis=-1)
print(y_true)
print(pred)
print(classification_report(y_true, pred,target_names=finallabels.values()))
# Out:
# 64/64 [==============================] - 13s 197ms/step
# [16, 10, 18, 18, 11, 18, 2, 13, 18, 3, 2, 8, 4, 19, 0, 1, 5, 5, 10, 10, 19, 0, 18, 11, 18, 3, 19, 7, 10, 10, 14, 13, 6, 15, 2, 18, 14, 19, 0, 18, 0, 19, 18, 19, 10, 4, 2, 2, 18, 18, 18, 15, 6, 18, 19, 4, 11, 1, 8, 10, 4, 5, 5, 18, 4, 1, 4, 10, 16, 4, 4, 10, 19, 3, 5, 4, 3, 0, 4, 
 1, 2, 10, 4, 13, 10, 15, 9, 5, 18, 10, 17, 5, 0, 19, 0, 11, 19, 2, 1, 4, 4, 4, 18, 0, 4, 0, 18, 18, 18, 2, 11, 1, 19, 13, 18, 13, 14, 4, 12, 11, 18, 1, 1, 6, 10, 6, 18, 4, 18, 11, 15, 1, 0, 10, 4, 10, 0, 15, 18, 10, 3, 15, 18, 10, 4, 18, 1, 18, 7, 18, 18, 0, 1, 10, 2, 10, 10, 6, 5, 13, 15, 10, 3, 0, 19, 4, 11, 6, 4, 1, 10, 4, 0, 18, 0, 5, 18, 18, 5, 10, 6, 9, 8, 5, 1, 5, 10, 10, 2, 4, 10, 9, 11, 1, 1, 19, 19, 15, 1, 9, 18, 9, 1, 5, 0, 4, 4, 18, 13, 5, 11, 18, 10, 4, 0, 18, 18, 2, 5, 10, 3, 5, 0, 4, 19, 16, 4, 19, 4, 15, 15, 4, 19, 19, 18, 6, 6, 6, 4, 10, 10, 14, 9, 4, 10, 4, 12, 1, 5, 10, 17, 19, 3, 3, 11, 0, 18, 12, 0, 10, 18, 4, 5, 1, 3, 5, 13, 10, 3, 10, 0, 19, 19, 18, 5, 13, 4, 18, 18, 10, 4, 0, 1, 4, 18, 0, 18, 2, 18, 10, 5, 19, 18, 5, 2, 10, 3, 18, 5, 19, 18, 10, 10, 6, 13, 17, 16, 18, 10, 9, 16, 10, 13, 9, 1, 19, 18, 18, 10, 10, 10, 18, 3, 0, 5, 7, 18, 0, 18, 5, 1, 10, 18, 4, 3, 18, 18, 16, 13, 18, 18, 10, 10, 6, 2, 18, 1, 4, 3, 4, 10, 18, 18, 10, 0, 10, 19, 5, 7, 18, 19, 3, 4, 0, 6, 10, 10, 5, 18, 18, 19, 2, 18, 10, 10, 5, 10, 6, 14, 14, 0, 10, 1, 2, 2, 1, 10, 4, 0, 0, 4, 5, 4, 7, 5, 10, 19, 10, 13, 5, 9, 1, 10, 19, 18, 5, 18, 18, 18, 4, 2, 19, 4, 6, 5, 4, 5, 10, 4, 3, 13, 18, 18, 11, 3, 11, 10, 5, 10, 0, 5, 9, 4, 18, 10, 12, 12, 18, 4, 18, 15, 4, 5, 3, 5, 1, 18, 4, 18, 18, 3, 10, 8, 18, 2, 10, 0, 0, 2, 10, 11, 14]
# [13 10 18 ... 10 11 14]
#               precision    recall  f1-score   support
#
#      limit30       0.79      0.87      0.83        60
#      limit50       0.93      0.88      0.90        58
#      limit60       0.60      0.94      0.73        50
#      limit80       0.65      0.72      0.69        50
#       noleft       0.96      0.98      0.97       130
#      noright       0.98      0.91      0.94        92
#      nouturn       0.60      0.08      0.15        36
#   gostraight       0.75      1.00      0.86        12
#       goleft       0.88      0.88      0.88         8
#      goright       1.00      0.81      0.89        26
#    keepright       1.00      0.90      0.94       134
#   roundabout       0.70      0.96      0.81        24
#       danger       1.00      0.75      0.86         8
# pedestrcross       0.94      0.98      0.96        46
#    bikecross       0.75      1.00      0.86        12
#   childcross       1.00      0.88      0.94        26
#   traincross       1.00      0.90      0.95        10
# construction       1.00      1.00      1.00         6
#   nostopping       0.97      0.98      0.97       176
#      noentry       0.98      1.00      0.99        58
#
#     accuracy                           0.90      1022
#    macro avg       0.87      0.87      0.86      1022
# weighted avg       0.90      0.90      0.89      1022

# %% [markdown]
# Save model

# %%
model.save('model_2c.h5')
