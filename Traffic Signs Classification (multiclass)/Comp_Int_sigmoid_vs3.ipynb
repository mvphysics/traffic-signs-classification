# %% [markdown]
# Download and unzip dataset

# %%
import requests
from io import BytesIO
from zipfile import ZipFile
dataset = requests.get("https://www.dropbox.com/s/04r31l2whoyljz7/trafficsigns.zip?dl=1")
with ZipFile(BytesIO(dataset.content)) as z:
  z.extractall(".")
classlabels = requests.get("https://www.dropbox.com/s/lte4x88xdk9x4k2/classlabels.txt?dl=1")
with open("classlabels.txt", 'w') as outfile:
  outfile.write(classlabels.content.decode('utf-8'))

# %% [markdown]
# Read training set and test set

# %%
from tensorflow.keras.utils import load_img, image_dataset_from_directory
training_set = [(i, l) for i, l in image_dataset_from_directory('trafficsigns/train', image_size = (128, 128), batch_size = None, seed = 123)]
test_set = [(i, l) for i, l in image_dataset_from_directory('trafficsigns/test', image_size = (128, 128), batch_size = None, seed = 123)]

import json
with open("classlabels.txt") as infile:
  labels = dict((int(i), j) for i, j in json.loads(infile.read()).items())
print("The 20 classes are: " + ", ".join(str(l) for l in labels.values()))
# Out:
# Found 1792 files belonging to 20 classes.
# Found 1022 files belonging to 20 classes.
# The 20 classes are: limit30, limit50, limit60, limit80, noleft, noright, nouturn, gostraight, goleft, goright, keepright, roundabout, danger, pedestrcross, bikecross, childcross, traincross, construction, nostopping, noentry

# %% [markdown]
# Keep only specific class labels

# %%
from ctypes import sizeof
labels_to_keep = list(range(20)) # Change this to determine which labels to keep (or change to list(range(20)) to keep all labels)
num_classes = len(labels_to_keep)

import numpy as np
x_train = np.array([image for image, label in training_set if label in labels_to_keep])
y_train = np.array([labels_to_keep.index(label) for image, label in training_set if label in labels_to_keep])
x_test = np.array([image for image, label in test_set if label in labels_to_keep])
y_test = np.array([labels_to_keep.index(label) for image, label in test_set if label in labels_to_keep])


finallabels = dict([(i, labels[l]) for i, l in enumerate(labels_to_keep)])
print("The " + str(num_classes) + " classes are: " + ", ".join(str(l) for l in finallabels.values()))
# Out:
# The 20 classes are: limit30, limit50, limit60, limit80, noleft, noright, nouturn, gostraight, goleft, goright, keepright, roundabout, danger, pedestrcross, bikecross, childcross, traincross, construction, nostopping, noentry

# %% [markdown]
# Plot example data

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import array_to_img
fig = plt.figure()
for i in range(15):
  plt.subplot(3,5,i+1)
  plt.tight_layout()
  img = array_to_img(x_train[i])
  plt.imshow(img)
  plt.title(finallabels[y_train[i]])
  plt.xticks([])
  plt.yticks([])

# %% [markdown]
# Set model parameters and use the image data format of Tensorflow

# %%
img_width, img_height = 128, 128
input_shape = (img_width, img_height, 3)

# %%
import keras
num_classes = 20
y_train = keras.utils.np_utils.to_categorical(y_train, num_classes)
y_test = keras.utils.np_utils.to_categorical(y_test, num_classes)
print(type(y_train))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# Create a neural network with 4 convolutional layers and 2 dense layers

# %%
from keras.layers import Convolution2D, MaxPooling2D, Dropout, Flatten, Dense
from keras.models import Sequential

model = Sequential()
model.add(Convolution2D(32, (5, 5), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Convolution2D(32, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Convolution2D(32, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Convolution2D(64, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='sigmoid'))

model.summary()
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 124, 124, 32)      2432
#
#  max_pooling2d (MaxPooling2D  (None, 62, 62, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 58, 58, 32)        25632
#
#  max_pooling2d_1 (MaxPooling  (None, 29, 29, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 32)        25632
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 64)          51264
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  dropout (Dropout)           (None, 4, 4, 64)          0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 128)               131200
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 20)                2580
#
# =================================================================
# Total params: 238,740
# Trainable params: 238,740
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Perform augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(rescale=1. / 255, shear_range=0.2, zoom_range=0.2,brightness_range=[0.4,0.9], validation_split=0.3)
test_datagen=ImageDataGenerator(rescale=1. / 255, shear_range=0.2, zoom_range=0.2,brightness_range=[0.4,0.9])

# %% [markdown]
# Train the model

# %%
history=model.fit(datagen.flow(x_train,y_train,batch_size=16,seed=0,subset='training'),steps_per_epoch=len(x_train)*0.3// 16,epochs=50,verbose=1,validation_data=datagen.flow(x_train,y_train,batch_size=16,seed=0,subset='validation') ,shuffle=True)
# Out:
# Epoch 1/50
# 33/33 [==============================] - 30s 870ms/step - loss: 2.8874 - accuracy: 0.1629 - val_loss: 2.7101 - val_accuracy: 0.2663
# Epoch 2/50
# 33/33 [==============================] - 18s 533ms/step - loss: 2.4095 - accuracy: 0.2987 - val_loss: 1.9261 - val_accuracy: 0.4600
# Epoch 3/50
# 33/33 [==============================] - 18s 558ms/step - loss: 1.9237 - accuracy: 0.4545 - val_loss: 1.4920 - val_accuracy: 0.5568
# Epoch 4/50
# 33/33 [==============================] - 19s 588ms/step - loss: 1.5209 - accuracy: 0.5455 - val_loss: 1.4215 - val_accuracy: 0.5698
# Epoch 5/50
# 33/33 [==============================] - 20s 601ms/step - loss: 1.4614 - accuracy: 0.5701 - val_loss: 1.0870 - val_accuracy: 0.6536
# Epoch 6/50
# 33/33 [==============================] - 20s 601ms/step - loss: 1.2589 - accuracy: 0.6193 - val_loss: 1.1241 - val_accuracy: 0.6127
# Epoch 7/50
# 33/33 [==============================] - 21s 654ms/step - loss: 0.8853 - accuracy: 0.7254 - val_loss: 1.0259 - val_accuracy: 0.6331
# Epoch 8/50
# 33/33 [==============================] - 19s 564ms/step - loss: 0.9229 - accuracy: 0.7008 - val_loss: 0.7926 - val_accuracy: 0.7207
# Epoch 9/50
# 33/33 [==============================] - 18s 549ms/step - loss: 0.8289 - accuracy: 0.7187 - val_loss: 0.6351 - val_accuracy: 0.7318
# Epoch 10/50
# 33/33 [==============================] - 18s 533ms/step - loss: 0.6718 - accuracy: 0.7514 - val_loss: 0.5569 - val_accuracy: 0.8380
# Epoch 11/50
# 33/33 [==============================] - 18s 558ms/step - loss: 0.6079 - accuracy: 0.8087 - val_loss: 0.5582 - val_accuracy: 0.7598
# Epoch 12/50
# 33/33 [==============================] - 17s 531ms/step - loss: 0.5995 - accuracy: 0.7823 - val_loss: 0.3832 - val_accuracy: 0.8845
# Epoch 13/50
# 33/33 [==============================] - 18s 543ms/step - loss: 0.5379 - accuracy: 0.8092 - val_loss: 0.4355 - val_accuracy: 0.9181
# Epoch 14/50
# 33/33 [==============================] - 18s 557ms/step - loss: 0.4589 - accuracy: 0.8593 - val_loss: 0.1922 - val_accuracy: 0.9385
# Epoch 15/50
# 33/33 [==============================] - 19s 565ms/step - loss: 0.3438 - accuracy: 0.8788 - val_loss: 0.2253 - val_accuracy: 0.9050
# Epoch 16/50
# 33/33 [==============================] - 18s 551ms/step - loss: 0.3673 - accuracy: 0.8902 - val_loss: 0.2497 - val_accuracy: 0.9181
# Epoch 17/50
# 33/33 [==============================] - 17s 525ms/step - loss: 0.3459 - accuracy: 0.8748 - val_loss: 0.2076 - val_accuracy: 0.9218
# Epoch 18/50
# 33/33 [==============================] - 18s 554ms/step - loss: 0.2666 - accuracy: 0.9152 - val_loss: 0.1225 - val_accuracy: 0.9590
# Epoch 19/50
# 33/33 [==============================] - 18s 546ms/step - loss: 0.2555 - accuracy: 0.9186 - val_loss: 0.1355 - val_accuracy: 0.9628
# Epoch 20/50
# 33/33 [==============================] - 18s 547ms/step - loss: 0.2033 - accuracy: 0.9326 - val_loss: 0.0890 - val_accuracy: 0.9777
# Epoch 21/50
# 33/33 [==============================] - 18s 541ms/step - loss: 0.2156 - accuracy: 0.9280 - val_loss: 0.1006 - val_accuracy: 0.9665
# Epoch 22/50
# 33/33 [==============================] - 18s 539ms/step - loss: 0.2289 - accuracy: 0.9191 - val_loss: 0.0791 - val_accuracy: 0.9739
# Epoch 23/50
# 33/33 [==============================] - 19s 564ms/step - loss: 0.1255 - accuracy: 0.9564 - val_loss: 0.1244 - val_accuracy: 0.9572
# Epoch 24/50
# 33/33 [==============================] - 18s 543ms/step - loss: 0.1163 - accuracy: 0.9640 - val_loss: 0.0216 - val_accuracy: 0.9944
# Epoch 25/50
# 33/33 [==============================] - 19s 580ms/step - loss: 0.2054 - accuracy: 0.9508 - val_loss: 0.0717 - val_accuracy: 0.9814
# Epoch 26/50
# 33/33 [==============================] - 19s 589ms/step - loss: 0.1390 - accuracy: 0.9527 - val_loss: 0.0661 - val_accuracy: 0.9814
# Epoch 27/50
# 33/33 [==============================] - 17s 525ms/step - loss: 0.1556 - accuracy: 0.9595 - val_loss: 0.0404 - val_accuracy: 0.9944
# Epoch 28/50
# 33/33 [==============================] - 18s 539ms/step - loss: 0.1018 - accuracy: 0.9659 - val_loss: 0.0317 - val_accuracy: 0.9888
# Epoch 29/50
# 33/33 [==============================] - 18s 558ms/step - loss: 0.1039 - accuracy: 0.9711 - val_loss: 0.0200 - val_accuracy: 0.9926
# Epoch 30/50
# 33/33 [==============================] - 19s 571ms/step - loss: 0.1293 - accuracy: 0.9621 - val_loss: 0.0156 - val_accuracy: 0.9963
# Epoch 31/50
# 33/33 [==============================] - 17s 532ms/step - loss: 0.0369 - accuracy: 0.9865 - val_loss: 0.0789 - val_accuracy: 0.9795
# Epoch 32/50
# 33/33 [==============================] - 18s 562ms/step - loss: 0.1124 - accuracy: 0.9583 - val_loss: 0.0619 - val_accuracy: 0.9795
# Epoch 33/50
# 33/33 [==============================] - 17s 521ms/step - loss: 0.0784 - accuracy: 0.9769 - val_loss: 0.0492 - val_accuracy: 0.9926
# Epoch 34/50
# 33/33 [==============================] - 17s 531ms/step - loss: 0.1152 - accuracy: 0.9692 - val_loss: 0.0092 - val_accuracy: 0.9963
# Epoch 35/50
# 33/33 [==============================] - 19s 583ms/step - loss: 0.0655 - accuracy: 0.9867 - val_loss: 0.0104 - val_accuracy: 0.9963
# Epoch 36/50
# 33/33 [==============================] - 19s 565ms/step - loss: 0.0688 - accuracy: 0.9792 - val_loss: 0.0297 - val_accuracy: 0.9944
# Epoch 37/50
# 33/33 [==============================] - 18s 537ms/step - loss: 0.0568 - accuracy: 0.9773 - val_loss: 0.0209 - val_accuracy: 0.9944
# Epoch 38/50
# 33/33 [==============================] - 19s 565ms/step - loss: 0.0499 - accuracy: 0.9867 - val_loss: 0.0266 - val_accuracy: 0.9944
# Epoch 39/50
# 33/33 [==============================] - 17s 528ms/step - loss: 0.0451 - accuracy: 0.9865 - val_loss: 0.1760 - val_accuracy: 0.9739
# Epoch 40/50
# 33/33 [==============================] - 18s 543ms/step - loss: 0.1246 - accuracy: 0.9697 - val_loss: 0.0322 - val_accuracy: 0.9926
# Epoch 41/50
# 33/33 [==============================] - 19s 566ms/step - loss: 0.0483 - accuracy: 0.9867 - val_loss: 0.0251 - val_accuracy: 0.9888
# Epoch 42/50
# 33/33 [==============================] - 18s 552ms/step - loss: 0.0483 - accuracy: 0.9830 - val_loss: 0.0529 - val_accuracy: 0.9870
# Epoch 43/50
# 33/33 [==============================] - 18s 533ms/step - loss: 0.0334 - accuracy: 0.9846 - val_loss: 0.1798 - val_accuracy: 0.9628
# Epoch 44/50
# 33/33 [==============================] - 18s 559ms/step - loss: 0.1345 - accuracy: 0.9659 - val_loss: 0.0320 - val_accuracy: 0.9944
# Epoch 45/50
# 33/33 [==============================] - 18s 558ms/step - loss: 0.0680 - accuracy: 0.9830 - val_loss: 0.0429 - val_accuracy: 0.9888
# Epoch 46/50
# 33/33 [==============================] - 19s 562ms/step - loss: 0.0617 - accuracy: 0.9865 - val_loss: 0.0152 - val_accuracy: 0.9907
# Epoch 47/50
# 33/33 [==============================] - 19s 578ms/step - loss: 0.0749 - accuracy: 0.9792 - val_loss: 0.0196 - val_accuracy: 0.9963
# Epoch 48/50
# 33/33 [==============================] - 17s 530ms/step - loss: 0.1005 - accuracy: 0.9788 - val_loss: 0.0771 - val_accuracy: 0.9832
# Epoch 49/50
# 33/33 [==============================] - 18s 564ms/step - loss: 0.0362 - accuracy: 0.9886 - val_loss: 0.0562 - val_accuracy: 0.9963
# Epoch 50/50
# 33/33 [==============================] - 17s 525ms/step - loss: 0.1300 - accuracy: 0.9769 - val_loss: 0.0266 - val_accuracy: 0.9926

# %% [markdown]
# Training and validation visualization

# %%
import matplotlib.pyplot as plt
train_acc=history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(1,51)
plt.plot(epochs, train_acc, 'g', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.xlim(1,50)
plt.ylim(0,1)
plt.grid(ls='dashed',c='grey')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1,51)
plt.plot(epochs, train_loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.xlim(1,50)
plt.ylim(0,3)
plt.grid(ls='dashed',c='grey')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Get loss and accuracy on test set

# %%
score = model.evaluate(test_datagen.flow(x_test, y_test,batch_size=16,seed=0), verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 64/64 [==============================] - 9s 140ms/step - loss: 0.8225 - accuracy: 0.8415
# Test loss: 0.8224779963493347
# Test accuracy: 0.8414872884750366

# %% [markdown]
# Get Classification Report

# %%
from sklearn.metrics import classification_report, confusion_matrix

def cat_to_num(c):
  for i in range(len(c)+1):
    if c[i]==1:
      return i
test=test_datagen.flow(x_test, y_test,batch_size=16,seed=0)
y_true=[]
for i in range (64):
  b=test[i]
  b=b[1]
  for j in range(len(b)):
    y_true.append(cat_to_num(b[j]))
pred = model.predict(test).argmax(axis=-1)
print(y_true)
print(pred)
print(classification_report(y_true, pred,target_names=finallabels.values()))
# Out:
# 64/64 [==============================] - 9s 140ms/step
# [16, 10, 18, 18, 11, 18, 2, 13, 18, 3, 2, 8, 4, 19, 0, 1, 5, 5, 10, 10, 19, 0, 18, 11, 18, 3, 19, 7, 10, 10, 14, 13, 6, 15, 2, 18, 14, 19, 0, 18, 0, 19, 18, 19, 10, 4, 2, 2, 18, 18, 18, 15, 6, 18, 19, 4, 11, 1, 8, 10, 4, 5, 5, 18, 4, 1, 4, 10, 16, 4, 4, 10, 19, 3, 5, 4, 3, 0, 4, 16, 6, 18, 1, 4, 4, 10, 4, 4, 4, 11, 18, 2, 9, 4, 18, 18, 6, 18, 1, 5, 1, 4, 5, 10, 10, 4, 3, 2, 11, 18, 18, 10, 18, 4, 10, 5, 18, 9, 4, 5, 18, 2, 18, 5, 19, 10, 5, 4, 13, 4, 18, 10, 3, 10, 5, 13, 2, 15, 1, 19, 10, 15, 2, 13, 4, 6, 15, 13, 4, 13, 0, 13, 6, 10, 19, 3, 4, 18, 1, 9, 17, 4, 2, 18, 5, 10, 0, 10, 4, 18, 9, 4, 1, 5, 18, 18, 18, 5, 5, 3, 18, 10, 4, 18, 3, 10, 5, 1, 10, 5, 19, 0, 19, 18, 19, 4, 19, 10, 18, 5, 9, 5, 7, 10, 5, 6, 18, 18, 4, 10, 10, 10, 19, 18, 4, 13, 10, 18, 18, 18, 5, 3, 13, 3, 5, 4, 0, 18, 9, 10, 18, 4, 1, 2, 6, 18, 6, 3, 4, 13, 18, 4, 13, 9, 9, 5, 5, 0, 5, 9, 18, 4, 18, 3, 5, 6, 19, 13, 2, 10, 5, 15, 16, 11, 0, 4, 4, 3, 19, 1, 6, 12, 18, 10, 5, 18, 10, 5, 8, 2, 19, 4, 5, 15, 1, 18, 13, 10, 10, 0, 13, 13, 4, 18, 18, 3, 10, 1, 15, 18, 2, 10, 19, 10, 13, 8, 3, 3, 3, 18, 13, 4, 10, 11, 0, 4, 1, 18, 4, 11, 18, 11, 18, 10, 1, 18, 18, 2, 0, 18, 5, 9, 9, 5, 13, 5, 4, 4, 1, 4, 6, 6, 10, 19, 3, 18, 16, 4, 10, 5, 13, 4, 19, 15, 9, 4, 5, 0, 13, 18, 0, 13, 13, 2, 2, 4, 0, 5, 18, 13, 5, 18, 2, 18, 8, 17, 1, 18, 0, 7, 4, 4, 3, 0, 13, 18, 11, 10, 3, 15, 11, 13, 10, 13, 12, 19, 18, 10, 5, 0, 4, 5, 10, 2, 1, 18, 15, 18, 4, 4, 18, 4, 2, 18, 4, 1, 18, 6, 19, 10, 5, 3, 2, 5, 2, 10, 4, 4, 0, 3, 5, 10, 4, 18, 2, 2, 4, 9, 18, 13, 3, 0, 6, 18, 18, 1, 13, 4, 4, 18, 18, 5, 12, 1, 4, 0, 19, 6, 3, 10, 4, 4, 11, 7, 7, 10, 10, 10, 10, 10, 2, 18, 18, 15, 7, 18, 2, 4, 4, 10, 3, 1, 4, 10, 10, 5, 1, 19, 4, 19, 5, 5, 2, 18, 0, 4, 6, 18, 15, 10, 18, 6, 18, 19, 0, 5, 10, 6, 1, 3, 5, 4, 18, 5, 14, 7, 0, 9, 14, 1, 18, 0, 19, 5, 18, 18, 5, 18, 13, 3, 1, 0, 10, 19, 4, 4, 19, 13, 1, 0, 6, 5, 0, 15, 10, 4, 14, 2, 5, 10, 13, 3, 4, 5, 4, 18, 2, 18, 7, 18, 13, 10, 1, 18, 6, 10, 2, 11, 10, 18, 16, 1, 6, 10, 1, 19, 10, 18, 19, 18, 19, 3, 9, 18, 8, 10, 2, 0, 6, 10, 15, 10, 18, 18, 10, 1, 4, 2, 9, 4, 2, 15, 18, 5, 19, 4, 2, 14, 4, 14, 1, 18, 4, 0, 4, 4, 3, 10, 5, 18, 4, 18, 17, 4, 3, 18, 19, 18, 3, 1, 10, 15, 5, 3, 4, 13, 5, 18, 18, 1, 2, 10, 4, 13, 10, 15, 9, 5, 18, 10, 17, 5, 0, 19, 0, 11, 19, 2, 1, 4, 4, 4, 18, 0, 4, 0, 18, 18, 18, 2, 11, 1, 19, 13, 18, 13, 14, 4, 12, 11, 18, 1, 1, 6, 10, 6, 18, 4, 18, 11, 15, 1, 0, 10, 4, 10, 0, 15, 18, 10, 3, 15, 18, 10, 4, 18, 1, 18, 7, 18, 18, 0, 1, 10, 2, 10, 10, 6, 5, 13, 15, 10, 3, 0, 19, 4, 11, 6, 4, 1, 10, 4, 0, 18, 0, 5, 18, 18, 5, 10, 6, 9, 8, 5, 1, 5, 10, 10, 2, 4, 10, 9, 11, 1, 1, 19, 19, 15, 1, 9, 18, 9, 1, 5, 0, 4, 4, 18, 13, 5, 11, 18, 10, 4, 0, 18, 18, 2, 5, 10, 3, 5, 0, 4, 19, 16, 4, 19, 4, 15, 15, 4, 19, 19, 18, 6, 6, 6, 4, 10, 10, 14, 9, 4, 10, 4, 12, 1, 5, 10, 17, 19, 3, 3, 11, 0, 18, 12, 0, 10, 18, 4, 5, 1, 3, 5, 13, 10, 3, 10, 0, 19, 19, 18, 5, 13, 4, 18, 18, 10, 4, 0, 1, 4, 18, 0, 18, 2, 18, 10, 5, 19, 18, 5, 2, 10, 3, 18, 5, 19, 18, 10, 10, 6, 13, 17, 16, 18, 10, 9, 16, 10, 13, 9, 1, 19, 18, 18, 10, 10, 10, 18, 3, 0, 5, 7, 18, 0, 18, 5, 1, 10, 18, 4, 3, 18, 18, 16, 13, 18, 18, 10, 10, 6, 2, 18, 1, 4, 3, 4, 10, 18, 18, 10, 0, 10, 19, 5, 7, 18, 19, 3, 4, 0, 6, 10, 10, 5, 18, 18, 19, 2, 18, 10, 10, 5, 10, 6, 14, 14, 0, 10, 1, 2, 2, 1, 10, 4, 0, 0, 4, 5, 4, 7, 5, 10, 19, 10, 13, 5, 9, 1, 10, 19, 18, 5, 18, 18, 18, 4, 2, 19, 4, 6, 5, 4, 5, 10, 4, 3, 13, 18, 18, 11, 3, 11, 10, 5, 10, 0, 5, 9, 4, 18, 10, 12, 12, 18, 4, 18, 15, 4, 5, 3, 5, 1, 18, 4, 18, 18, 3, 10, 8, 18, 2, 10, 0, 0, 2, 10, 11, 14]
# [15 10 18 ... 10 11 14]
#               precision    recall  f1-score   support
#
#      limit30       0.69      0.55      0.61        60
#      limit50       0.92      0.79      0.85        58
#      limit60       0.71      0.80      0.75        50
#      limit80       0.44      0.82      0.57        50
#       noleft       0.84      0.98      0.91       130
#      noright       0.93      0.55      0.69        92
#      nouturn       0.88      0.19      0.32        36
#   gostraight       1.00      1.00      1.00        12
#       goleft       1.00      1.00      1.00         8
#      goright       1.00      1.00      1.00        26
#    keepright       0.95      0.94      0.94       134
#   roundabout       0.81      0.92      0.86        24
#       danger       0.30      0.75      0.43         8
# pedestrcross       0.90      0.96      0.93        46
#    bikecross       0.63      1.00      0.77        12
#   childcross       0.72      0.81      0.76        26
#   traincross       0.75      0.60      0.67        10
# construction       0.55      1.00      0.71         6
#   nostopping       1.00      0.95      0.98       176
#      noentry       1.00      0.86      0.93        58
#
#     accuracy                           0.83      1022
#    macro avg       0.80      0.82      0.78      1022
# weighted avg       0.87      0.83      0.83      1022

# %% [markdown]
# Save model

# %%
model.save('model_1c.h5')
